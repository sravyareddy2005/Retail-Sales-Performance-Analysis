# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-d4dfe3b0-cdbe-4d4c-b705-e9a0e333b3b8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d4dfe3b0-cdbe-4d4c-b705-e9a0e333b3b8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as np

data = np.genfromtxt(
    'retail_sales_dataset.csv',
    delimiter=',',
    skip_header=1
)

# %%
data.shape
# Out:
# (1000, 9)

# %%
data[:5]
# Out:
# array([[   1.,   nan,   nan,   nan,   34.,   nan,    3.,   50.,  150.],
#        [   2.,   nan,   nan,   nan,   26.,   nan,    2.,  500., 1000.],
#        [   3.,   nan,   nan,   nan,   50.,   nan,    1.,   30.,   30.],
#        [   4.,   nan,   nan,   nan,   37.,   nan,    1.,  500.,  500.],
#        [   5.,   nan,   nan,   nan,   30.,   nan,    2.,   50.,  100.]])

# %%
data_all = np.genfromtxt(
    'retail_sales_dataset.csv',
    delimiter=',',
    skip_header=1,
    dtype=str
)

# %%
data_all[:5]
# Out:
# array([['1', '2023-11-24', 'CUST001', 'Male', '34', 'Beauty', '3', '50',
#         '150'],
#        ['2', '2023-02-27', 'CUST002', 'Female', '26', 'Clothing', '2',
#         '500', '1000'],
#        ['3', '2023-01-13', 'CUST003', 'Male', '50', 'Electronics', '1',
#         '30', '30'],
#        ['4', '2023-05-21', 'CUST004', 'Male', '37', 'Clothing', '1',
#         '500', '500'],
#        ['5', '2023-05-06', 'CUST005', 'Male', '30', 'Beauty', '2', '50',
#         '100']], dtype='<U11')

# %%
headers = np.genfromtxt(
    'retail_sales_dataset.csv',
    delimiter=',',
    max_rows=1,
    dtype=str
)

headers
# Out:
# array(['Transaction ID', 'Date', 'Customer ID', 'Gender', 'Age',
#        'Product Category', 'Quantity', 'Price per Unit', 'Total Amount'],
#       dtype='<U16')

# %%
age = data_all[:, 4].astype(int)
quantity = data_all[:, 6].astype(int)
price = data_all[:, 7].astype(int)
total = data_all[:, 8].astype(int)

# %%
total_sales = np.sum(total)
total_sales
# Out:
# np.int64(456000)

# %%
average_sales = np.mean(total)
average_sales
# Out:
# np.float64(456.0)

# %%
max_sale = np.max(total)
max_sale
# Out:
# np.int64(2000)

# %%
min_sale = np.min(total)
min_sale
# Out:
# np.int64(25)

# %%
median_sale = np.median(total)
median_sale
# Out:
# np.float64(135.0)

# %%
std_sale = np.std(total)
std_sale
# Out:
# np.float64(559.7175627046198)

# %%
variance_sale = np.var(total)
variance_sale
# Out:
# np.float64(313283.75)

# %%
total_quantity = np.sum(quantity)
total_quantity
# Out:
# np.int64(2514)

# %%
avg_quantity = np.mean(quantity)
avg_quantity
# Out:
# np.float64(2.514)

# %%
max_quantity = np.max(quantity)
max_quantity
# Out:
# np.int64(4)

# %%
int(np.max(quantity))
# Out:
# 4
